# %%
# This script will detect faces via your webcam.
# Tested with OpenCV3

import cv2

cap = cv2.VideoCapture(0)

# Create the haar cascade
def load_cascade_classifier_xml():
    return cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
faceCascade = load_cascade_classifier_xml()
def find_faces_in_img(grayimg):
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(48, 48),
        maxSize = (300,300)
        #flags = cv2.CV_HAAR_SCALE_IMAGE
    )

    print("Found {0} faces!".format(len(faces)))

    # Draw a rectangle around the faces
    facecoordslist = []
    imgs = []
    for (x, y, w, h) in faces:
            tup = ( y, y+h,x, x+w)
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
            imglist.append(tup)
    print(imglist)
    for (y1,y2,x1,x2) in imglist:
        img= frame[y1:y2,x1:x2]
        imgs.append(img)
    return facecoordslist,imgs
while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Detect faces in the image
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(48, 48),
        maxSize = (300,300)
        #flags = cv2.CV_HAAR_SCALE_IMAGE
    )

    print("Found {0} faces!".format(len(faces)))

    # Draw a rectangle around the faces
    imglist = []

    for (x, y, w, h) in faces:
            tup = ( y, y+h,x, x+w)
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
            imglist.append(tup)
    print(imglist)
    for (y1,y2,x1,x2) in imglist:
        img= frame[y1:y2,x1:x2]
        cv2.imshow('amir',img)
    # Display the resulting frame
    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# Found 1 faces!
# [(162, 421, 630, 889)]
# Found 1 faces!
# [(156, 422, 632, 898)]
# Found 1 faces!
# [(159, 412, 636, 889)]
# Found 1 faces!
# [(150, 411, 628, 889)]
# Found 1 faces!
# [(152, 410, 629, 887)]
# Found 1 faces!
# [(156, 421, 627, 892)]
# Found 1 faces!
# [(150, 418, 626, 894)]
# Found 1 faces!
# [(158, 422, 630, 894)]
# Found 1 faces!
# [(167, 425, 628, 886)]
# Found 1 faces!
# [(167, 430, 623, 886)]
# Found 1 faces!
# [(171, 432, 619, 880)]
# Found 1 faces!
# [(167, 423, 617, 873)]
# Found 1 faces!
# [(163, 421, 612, 870)]
# Found 1 faces!
# [(158, 418, 610, 870)]
# Found 1 faces!
# [(157, 419, 608, 870)]
# Found 1 faces!
# [(159, 423, 607, 871)]
# Found 1 faces!
# [(158, 419, 607, 868)]
# Found 1 faces!
# [(158, 421, 607, 870)]
# Found 1 faces!
# [(161, 429, 604, 872)]
# Found 1 faces!
# [(160, 421, 607, 868)]
# Found 1 faces!
# [(158, 421, 603, 866)]
# Found 1 faces!
# [(158, 420, 605, 867)]
# Found 1 faces!
# [(156, 419, 601, 864)]
# Found 1 faces!
# ...

# %%
    faceCascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the image
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(48, 48),
        maxSize = (300,300)
        #flags = cv2.CV_HAAR_SCALE_IMAGE
    )

    print("Found {0} faces!".format(len(faces)))

    # Draw a rectangle around the faces
    imglist = []
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        img= frame[y:y+h,x:x+w]
        imglist.append(img)
    print(imglist)

# %%
imglist = []

for (x, y, w, h) in faces:
        tup = ( y, y+h,x, x+w)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        imglist.append(tup)
print(imglist)
for (y1,y2,x1,x2) in imglist:
    img= frame[y1:y2,x1:x2]
    cv2.imshow('amir',img)
# Out:
# [(129, 403, 598, 872)]
